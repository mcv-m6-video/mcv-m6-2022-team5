# %%
import sys
IN_COLAB = 'google.colab' in sys.modules

if IN_COLAB:
  from google.colab import drive
  drive.mount('/content/drive', force_remount=True)
  # %cd /content/drive/MyDrive/M6_Project/week1
  # !ls

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from optical_flow import *

# %%
data_path = '../datasets/results_opticalflow_kitti'

# %% [markdown]
# ## Sequence 45

# %% [markdown]
# ### Ground Truth

# %%
img_path = os.path.join(data_path,'000045_10.png')
optical_flow_path = os.path.join(data_path,'gt_000045_10_noc.png')
flow = load_flow(optical_flow_path)
plot_optical_flow(flow)

# %%
plot_optical_flow_field(img_path, flow)

# %% [markdown]
# ### Kitti estimate

# %%
img_path = os.path.join(data_path,'000045_10.png')
optical_flow_path = os.path.join(data_path,'LKflow_000045_10.png')
flow = load_flow(optical_flow_path)
plot_optical_flow(flow)

# %%
plot_optical_flow_field(img_path, flow)

# %% [markdown]
# ## Sequence 157

# %% [markdown]
# ### Ground Truth

# %%
img_path = os.path.join(data_path,'000157_10.png')
optical_flow_path = os.path.join(data_path,'gt_000157_10_occ.png')
flow = load_flow(optical_flow_path)
plot_optical_flow(flow)

# %%
plot_optical_flow_field(img_path, flow)

# %% [markdown]
# ### Kitti estimate

# %%
img_path = os.path.join(data_path,'000157_10.png')
optical_flow_path = os.path.join(data_path,'LKflow_000157_10.png')
flow = load_flow(optical_flow_path)
plot_optical_flow(flow)

# %%
plot_optical_flow_field(img_path, flow)
